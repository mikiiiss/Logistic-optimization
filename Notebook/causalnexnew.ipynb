# %%
#create an empty structure model.import warnings
import warnings
from causalnex.structure import StructureModel

warnings.filterwarnings("ignore")  # silence warnings

sm = StructureModel()

# %%
# import the dataset
import pandas as pd

# %%
data = pd.read_csv('/home/miki/Logistic-optimization/Notebook/merged_result.csv')
data.head(5)
# Out:
#    id  order_id  driver_id driver_action       lat       lng  \
# 0   1    392001     243828      accepted  6.602207  3.270465
# 1   2    392001     243588      rejected  6.592097  3.287445
# 2   3    392001     243830      rejected  6.596133  3.281784
# 3   4    392001     243539      rejected  6.596142  3.280526
# 4   5    392001     171653      rejected  6.609232  3.288800
#
#            trip_origin     trip_destination  weekday trip_start_date  holiday  \
# 0  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 1  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 2  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 3  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 4  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
#
#    rain   distance       speed
# 0   0.0  13.039051  216.316059
# 1   0.0  13.039051  216.316059
# 2   0.0  13.039051  216.316059
# 3   0.0  13.039051  216.316059
# 4   0.0  13.039051  216.316059

# %%
data["holiday"].value_counts()
# Out:
# 0.0    1555718
# Name: holiday, dtype: int64

# %%
# choose non-numeric columns
import numpy as np

struct_data = data.copy()
non_numeric_columns = list(struct_data.select_dtypes(exclude=[np.number]).columns)

print(non_numeric_columns)
# Out:
# ['driver_action', 'trip_origin', 'trip_destination', 'trip_start_date']

# %%
data.head(5)
# Out:
#    id  order_id  driver_id driver_action       lat       lng  \
# 0   1    392001     243828      accepted  6.602207  3.270465
# 1   2    392001     243588      rejected  6.592097  3.287445
# 2   3    392001     243830      rejected  6.596133  3.281784
# 3   4    392001     243539      rejected  6.596142  3.280526
# 4   5    392001     171653      rejected  6.609232  3.288800
#
#            trip_origin     trip_destination  weekday trip_start_date  holiday  \
# 0  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 1  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 2  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 3  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
# 4  6.6010417,3.2766339  6.4501069,3.3916154      1.0      2021-07-01      0.0
#
#    rain   distance       speed
# 0   0.0  13.039051  216.316059
# 1   0.0  13.039051  216.316059
# 2   0.0  13.039051  216.316059
# 3   0.0  13.039051  216.316059
# 4   0.0  13.039051  216.316059

# %%
drop_col = ['id','lat','lng','driver_id']
data = data.drop(columns=drop_col)
data.head(5)
# Out:
#    order_id driver_action          trip_origin     trip_destination  weekday  \
# 0    392001      accepted  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 1    392001      rejected  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 2    392001      rejected  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 3    392001      rejected  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 4    392001      rejected  6.6010417,3.2766339  6.4501069,3.3916154      1.0
#
#   trip_start_date  holiday  rain   distance       speed
# 0      2021-07-01      0.0   0.0  13.039051  216.316059
# 1      2021-07-01      0.0   0.0  13.039051  216.316059
# 2      2021-07-01      0.0   0.0  13.039051  216.316059
# 3      2021-07-01      0.0   0.0  13.039051  216.316059
# 4      2021-07-01      0.0   0.0  13.039051  216.316059

# %%
# Replace 'rejected' with 0 and 'accepted' with 1 in the 'driver_action' column
data['driver_action'] = data['driver_action'].replace({'rejected': 0, 'accepted': 1})

# Save the modified DataFrame to a new CSV file
#data.to_csv("mergeds.csv", index=False)

# %%
data.head(5)
# Out:
#    order_id  driver_action          trip_origin     trip_destination  weekday  \
# 0    392001              1  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 1    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 2    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 3    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 4    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
#
#   trip_start_date  holiday  rain   distance       speed
# 0      2021-07-01      0.0   0.0  13.039051  216.316059
# 1      2021-07-01      0.0   0.0  13.039051  216.316059
# 2      2021-07-01      0.0   0.0  13.039051  216.316059
# 3      2021-07-01      0.0   0.0  13.039051  216.316059
# 4      2021-07-01      0.0   0.0  13.039051  216.316059

# %%
data = pd.read_csv('mergeds.csv')
data.head(5)
# Out:
#    id  driver_id  driver_action       lat       lng  weekday  holiday  rain  \
# 0   1     243828              1  6.602207  3.270465      1.0      0.0   0.0
# 1   2     243588              0  6.592097  3.287445      1.0      0.0   0.0
# 2   3     243830              0  6.596133  3.281784      1.0      0.0   0.0
# 3   4     243539              0  6.596142  3.280526      1.0      0.0   0.0
# 4   5     171653              0  6.609232  3.288800      1.0      0.0   0.0
#
#     distance       speed
# 0  13.039051  216.316059
# 1  13.039051  216.316059
# 2  13.039051  216.316059
# 3  13.039051  216.316059
# 4  13.039051  216.316059

# %%
 #  use label encoding non-numeric variables to make data numeric
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in non_numeric_columns:
    struct_data[col] = le.fit_transform(struct_data[col])

struct_data.head(5)
# Out:
#    id  order_id  driver_id  driver_action       lat       lng  trip_origin  \
# 0   1    392001     243828              0  6.602207  3.270465        11676
# 1   2    392001     243588              1  6.592097  3.287445        11676
# 2   3    392001     243830              1  6.596133  3.281784        11676
# 3   4    392001     243539              1  6.596142  3.280526        11676
# 4   5    392001     171653              1  6.609232  3.288800        11676
#
#    trip_destination  weekday  trip_start_date  holiday  rain   distance  \
# 0              3785      1.0                0      0.0   0.0  13.039051
# 1              3785      1.0                0      0.0   0.0  13.039051
# 2              3785      1.0                0      0.0   0.0  13.039051
# 3              3785      1.0                0      0.0   0.0  13.039051
# 4              3785      1.0                0      0.0   0.0  13.039051
#
#         speed
# 0  216.316059
# 1  216.316059
# 2  216.316059
# 3  216.316059
# 4  216.316059

# %%
import pandas as pd
import numpy as np

# Impute NaN with column means
for col in struct_data.columns:
    if struct_data[col].isnull().any():
        mean_value = struct_data[col].mean()
        struct_data[col].fillna(mean_value, inplace=True)

# %%
drop_cols = ['id','driver_id','lat','lng']

# %%
# data=data.drop(columns=drop_cols)
data.head(5)
# Out:
#    order_id  driver_action          trip_origin     trip_destination  weekday  \
# 0    392001              1  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 1    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 2    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 3    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
# 4    392001              0  6.6010417,3.2766339  6.4501069,3.3916154      1.0
#
#   trip_start_date  holiday  rain   distance       speed
# 0      2021-07-01      0.0   0.0  13.039051  216.316059
# 1      2021-07-01      0.0   0.0  13.039051  216.316059
# 2      2021-07-01      0.0   0.0  13.039051  216.316059
# 3      2021-07-01      0.0   0.0  13.039051  216.316059
# 4      2021-07-01      0.0   0.0  13.039051  216.316059

# %%
drop_cols = ['order_id','trip_origin','trip_start_date','trip_destination']

# %%
data=data.drop(columns=drop_cols)
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 data=data.drop(columns=drop_cols)
#       2 data.head(5)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['order_id', 'trip_origin', 'trip_start_date', 'trip_destination'] not found in axis"

# %%
data.head(5)
# Out:
#    driver_action  weekday  holiday  rain   distance       speed
# 0              1      1.0      0.0   0.0  13.039051  216.316059
# 1              0      1.0      0.0   0.0  13.039051  216.316059
# 2              0      1.0      0.0   0.0  13.039051  216.316059
# 3              0      1.0      0.0   0.0  13.039051  216.316059
# 4              0      1.0      0.0   0.0  13.039051  216.316059

# %%
m=data.isna().sum()
m
# Out:
# driver_action       0
# weekday          2022
# holiday          2022
# rain             2022
# distance         2022
# speed            2022
# dtype: int64

# %%
# Impute NaN with column means
for col in data.columns:
    if data[col].isnull().any():
        mean_value = data[col].mean()
        data[col].fillna(mean_value, inplace=True)

# %%
data.head(5)
# Out:
#    driver_action  weekday  holiday  rain   distance       speed
# 0              1      1.0      0.0   0.0  13.039051  216.316059
# 1              0      1.0      0.0   0.0  13.039051  216.316059
# 2              0      1.0      0.0   0.0  13.039051  216.316059
# 3              0      1.0      0.0   0.0  13.039051  216.316059
# 4              0      1.0      0.0   0.0  13.039051  216.316059

# %%
m=data.isna().sum()
m
# Out:
# driver_action    0
# weekday          0
# holiday          0
# rain             0
# distance         0
# speed            0
# dtype: int64

# %%
data.to_csv('for_normilization.csv', index=False)

# %%
data.dropna(inplace=True)

# %%
mb=data.isna().sum()
mb
# Out:
# driver_action    0
# weekday          0
# holiday          0
# rain             0
# distance         0
# speed            0
# dtype: int64

# %%
import numpy as np

struct_data = data.copy()

# %%
struct_data.head(5)
# Out:
#    driver_action  weekday  holiday  rain   distance       speed
# 0              1      1.0      0.0   0.0  13.039051  216.316059
# 1              0      1.0      0.0   0.0  13.039051  216.316059
# 2              0      1.0      0.0   0.0  13.039051  216.316059
# 3              0      1.0      0.0   0.0  13.039051  216.316059
# 4              0      1.0      0.0   0.0  13.039051  216.316059

# %%
# Impute NaN with column means
for col in struct_data.columns:
    if struct_data[col].isnull().any():
        mean_value = struct_data[col].mean()
        struct_data[col].fillna(mean_value, inplace=True)

# %%
struct_data.head(5)
# Out:
#    driver_action  weekday  holiday  rain   distance       speed
# 0              1      1.0      0.0   0.0  13.039051  216.316059
# 1              0      1.0      0.0   0.0  13.039051  216.316059
# 2              0      1.0      0.0   0.0  13.039051  216.316059
# 3              0      1.0      0.0   0.0  13.039051  216.316059
# 4              0      1.0      0.0   0.0  13.039051  216.316059

# %%
#apply the NOTEARS algorithm to learn the structure.

from causalnex.structure.notears import from_pandas
sm = from_pandas(struct_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 4
#       1 #apply the NOTEARS algorithm to learn the structure.
#       3 from causalnex.structure.notears import from_pandas
# ----> 4 sm = from_pandas(struct_data)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/causalnex/structure/notears.py:251, in from_pandas(X, max_iter, h_tol, w_threshold, tabu_edges, tabu_parent_nodes, tabu_child_nodes)
#     248 if tabu_child_nodes:
#     249     tabu_child_nodes = [col_idx[n] for n in tabu_child_nodes]
# --> 251 g = from_numpy(
#     252     data.values,
#     253     max_iter,
#     254     h_tol,
#     255     w_threshold,
#     256     tabu_edges,
#     257     tabu_parent_nodes,
#     258     tabu_child_nodes,
#     259 )
#     261 sm = StructureModel()
#     262 sm.add_nodes_from(data.columns)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/causalnex/structure/notears.py:121, in from_numpy(X, max_iter, h_tol, w_threshold, tabu_edges, tabu_parent_nodes, tabu_child_nodes)
#     105 _assert_all_finite(X)
#     107 bnds = [
#     108     (0, 0)
#     109     if i == j
#    (...)
#     118     for j in range(d)
#     119 ]
# --> 121 return _learn_structure(X, bnds, max_iter, h_tol, w_threshold)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/causalnex/structure/notears.py:425, in _learn_structure(X, bnds, max_iter, h_tol, w_threshold)
#     423 for n_iter in range(max_iter):
#     424     while (rho < 1e20) and (h_new > 0.25 * h or h_new == np.inf):
# --> 425         sol = sopt.minimize(_func, w_est, method="L-BFGS-B", jac=_grad, bounds=bnds)
#     426         w_new = sol.x
#     427         h_new = _h(w_new)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py:696, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#     695 elif meth == 'l-bfgs-b':
# --> 696     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                            callback=callback, **options)
#     698 elif meth == 'tnc':
#     699     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     700                         **options)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_lbfgsb_py.py:359, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     353 task_str = task.tobytes()
#     354 if task_str.startswith(b'FG'):
#     355     # The minimization routine wants f and g at the current x.
#     356     # Note that interruptions due to maxfun are postponed
#     357     # until the completion of the current minimization iteration.
#     358     # Overwrite f and g:
# --> 359     f, g = func_and_grad(x)
#     360 elif task_str.startswith(b'NEW_X'):
#     361     # new iteration
#     362     n_iterations += 1
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/Logistic-optimization/.venv/lib/python3.8/site-packages/causalnex/structure/notears.py:389, in _learn_structure.<locals>._func(w)
#     378 """
#     379 Objective function that the NOTEARS algorithm tries to minimise.
#     380
#    (...)
#     385     float: objective.
#     386 """
#     388 W = w.reshape([d, d])
# --> 389 loss = 0.5 / n * np.square(np.linalg.norm(X.dot(np.eye(d, d) - W), "fro"))
#     390 h = _h(W)
#     391 return loss + 0.5 * rho * h * h + alpha * h
#
# KeyboardInterrupt:
